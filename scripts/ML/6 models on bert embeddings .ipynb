.1191e-01 -3.5474e-01  7.1436e-01 -2.1741e-01 -2.5098e-01\n  4.9023e-01  9.9426e-02 -5.7144e-03 -1.0461e-01  4.6387e-02  5.8746e-02\n  1.9875e-03 -1.2262e-01  1.1024e-02  5.2643e-02 -1.8823e-01 -1.2312e-03\n -8.7585e-02 -4.8218e-01  1.6602e-01  2.5366e-01 -2.7686e-01 -2.5610e-01\n  5.4834e-01 -2.0251e-01 -6.6872e-03  1.9495e-01  2.2925e-01 -2.9834e-01\n  4.9530e-02  9.8114e-03  1.9568e-01  1.1490e-02 -3.3569e-01  2.2314e-01\n -1.3684e-01 -2.1545e-01 -4.7109e+00  2.4597e-02 -2.9321e-01  6.9580e-02\n  2.4182e-01 -3.4473e-01  3.2104e-02  1.2915e-01 -2.3047e-01  1.0857e-02\n -2.7051e-01 -1.2939e-01  1.9775e-01  2.4963e-02 -1.1029e-01  2.0447e-01\n  8 ...

# %%
len(df['embeddings'][0])
# Out:
# 9344

# %%
from sklearn.decomposition import PCA
#Convert embeddings from string to numpy arrays
def parse_embedding(embed_str):
    clean_str = embed_str.replace('[','').replace(']','').replace('\n',' ')
    return np.array([float(x) for x in clean_str.split()])
df['embedding_array'] = df['embeddings'].apply(parse_embedding)

embeddings_matrix = np.vstack(df['embedding_array'].values)
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings_matrix)

# %%
# I have 9344 embeddings. These will be too much for the model and will require
# higher computational cost so apply pca on it to reduce the dimensions into 2
# my eembeddings are in the string format inside the string there is a list such as 
# '[1.0  2.0 \n 3.0....]'. there are \n also so replace them by space and then apply PCA
# and reduce dimensionality components to 2

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

feature_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
X_features = StandardScaler().fit_transform(df[feature_cols])
X_combined = np.hstack([X_features, reduced_embeddings])
y = StandardScaler().fit_transform(df[['Adj Close']]).flatten()

X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, shuffle=False)

rf = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("MSE: ", (mean_squared_error(y_test, y_pred)))
print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))

test_size = len(y_test)
dates = df['Date']
plt.figure(figsize=(14, 7))
plt.plot(dates[-test_size:], y_test, label='Actual Price')
plt.plot(dates[-test_size:], y_pred, label='Predicted Price')
plt.title('Random Forest Price Prediction')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# MSE:  0.00018372795461538247
# RMSE:  0.013554628531073159

# %%
# I have my embeddings and tabular data I want to apply Random Forest on it by combining
# both features.
# Combine them and set adj close as target and do train test split
# normalize the tabular features as the values are so large
# dont shuffle the data in train test split as we have to follow sequence in bit coin predictios
# Apply random forest of sklearn on it and compute matrices for model evaluation
# plot the actual and predicted against each other

# %% [markdown]
# ## **XAI on Random Forest**

# %%
explainer = shap.TreeExplainer(rf)

shap_values = explainer.shap_values(X_test)

tabular_features = ['Open', 'High', 'Low', 'Close', 'Volume']
embedding_features = [f'emb_{i}' for i in range(reduced_embeddings.shape[1])]
all_feature_names = tabular_features + embedding_features

X_test_df = pd.DataFrame(X_test, columns=all_feature_names)

shap.summary_plot(shap_values, X_test_df, max_display=20)

# %%
# set a shap variable on random forest and make a summary plot to explain model

# %% [markdown]
# ## **Feature Importance**

# %%
importances = rf.feature_importances_

features = feature_cols + [f'Embedding_{i+1}' for i in range(reduced_embeddings.shape[1])]
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

# Sort the features by importance
importance_df = importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(6, 4))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances in Random Forest Model')
plt.show()

# %%
# compute the importance of each feature and plot it 
# arrange them so that i can get important feature easily

# %%
feature_cols = ['High', 'Low', 'Close']
X_features = StandardScaler().fit_transform(df[feature_cols])
X_combined = X_features
y = StandardScaler().fit_transform(df[['Adj Close']]).flatten()

X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, shuffle=False)

rfImp = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rfImp.fit(X_train, y_train)
y_pred = rfImp.predict(X_test)
print("MSE: ", mean_squared_error(y_test, y_pred))
print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))

test_size = len(y_test)
dates = df['Date']
plt.figure(figsize=(14, 7))
plt.plot(dates[-test_size:], y_test, label='Actual Price')
plt.plot(dates[-test_size:], y_pred, label='Predicted Price')
plt.title('Price Prediction with Important Feature')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# MSE:  0.00010952834017807875
# RMSE:  0.010465578826709909

# %% [markdown]
# # **LSTM**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Concatenate, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model

scaler = StandardScaler()
tabular_data = df[['Open', 'High', 'Low', 'Close', 'Volume']].values
tabular_data_scaled = scaler.fit_transform(tabular_data)

X_combined = np.concatenate([tabular_data_scaled, reduced_embeddings], axis=1)
y = StandardScaler().fit_transform(df[['Adj Close']]).flatten()

def create_sequences(data, targets, window_size=7):
    X, y_seq = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y_seq.append(targets[i])
    return np.array(X), np.array(y_seq)
X_sequences, y_sequences = create_sequences(X_combined, y)

X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_sequences, test_size=0.2, shuffle=False)

model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.1), LSTM(64), Dense(32, activation='relu'), Dense(1)])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error',
              metrics=['mae'])
history = model.fit( X_train, y_train, epochs=50, batch_size=64,
                    validation_data=(X_test, y_test), verbose=1)
y_pred = model.predict(X_test)

loss, mae = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss:.4f}, MAE: {mae:.4f}')
print('MSE :', mean_squared_error(y_test, y_pred))

test_size = len(y_test)
dates_test = df['Date'].values[-test_size:]
plt.figure(figsize=(14, 6))
plt.plot(dates_test, y_test, label='Actual Price')
plt.plot(dates_test, y_pred.flatten(), label='Predicted Price')
plt.title('7-Day LSTM Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price (Standardized)')
plt.legend()
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.7338 - mae: 0.6888 - val_loss: 0.1171 - val_mae: 0.3033
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0757 - mae: 0.2143 - val_loss: 0.0407 - val_mae: 0.1654
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0446 - mae: 0.1490 - val_loss: 0.0449 - val_mae: 0.1709
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0313 - mae: 0.1046 - val_loss: 0.0413 - val_mae: 0.1596
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0298 - mae: 0.0953 - val_loss: 0.0378 - val_mae: 0.1577
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0242 - mae: 0.0880 - val_loss: 0.0255 - val_mae: 0.1302
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0226 - mae: 0.0812 - val_loss: 0.0175 - val_mae: 0.1029
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0225 - mae: 0.0809 - val_loss: 0.0153 - val_mae: 0.0955
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0212 - mae: 0.0797 - val_loss: 0.0393 - val_mae: 0.1767
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0287 - mae: 0.0901 - val_loss: 0.0386 - val_mae: 0.1754
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185 - mae: 0.0702 - val_loss: 0.0183 - val_mae: 0.1115
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165 - mae: 0.0718 - val_loss: 0.0211 - val_mae: 0.1227
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0218 - mae: 0.0749 - val_loss: 0.0254 - val_mae: 0.1382
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0190 - mae: 0.0713 - val_loss: 0.0153 - val_mae: 0.1017
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0187 - mae: 0.0667 - val_loss: 0.0118 - val_mae: 0.0868
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0148 - mae: 0.0660 - val_loss: 0.0269 - val_mae: 0.1423
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0157 - mae: 0.0729 - val_loss: 0.0354 - val_mae: 0.1680
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144 - mae: 0.0660 - val_loss: 0.0246 - val_mae: 0.1357
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0162 - mae: 0.0685 - val_loss: 0.0146 - val_mae: 0.0992
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136 - mae: 0.0617 - val_loss: 0.0122 - val_mae: 0.0896
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0120 - mae: 0.0576 - val_loss: 0.0162 - val_mae: 0.1054
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136 - mae: 0.0616 - val_loss: 0.0225 - val_mae: 0.1294
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130 - mae: 0.0611 - val_loss: 0.0247 - val_mae: 0.1333
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105 - mae: 0.0569 - val_loss: 0.0282 - val_mae: 0.1473
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110 - mae: 0.0566 - val_loss: 0.0081 - val_mae: 0.0737
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0216 - mae: 0.0729 - val_loss: 0.0234 - val_mae: 0.1288
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108 - mae: 0.0571 - val_loss: 0.0349 - val_mae: 0.1651
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - mae: 0.0593 - val_loss: 0.0229 - val_mae: 0.1285
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0160 - mae: 0.0643 - val_loss: 0.0243 - val_mae: 0.1337
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - mae: 0.0660 - val_loss: 0.0103 - val_mae: 0.0804
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179 - mae: 0.0702 - val_loss: 0.0070 - val_mae: 0.0677
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176 - mae: 0.0640 - val_loss: 0.0068 - val_mae: 0.0663
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mae: 0.0543 - val_loss: 0.0187 - val_mae: 0.1124
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mae: 0.0537 - val_loss: 0.0145 - val_mae: 0.0954
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - mae: 0.0536 - val_loss: 0.0148 - val_mae: 0.0961
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - mae: 0.0574 - val_loss: 0.0169 - val_mae: 0.1050
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - mae: 0.0595 - val_loss: 0.0142 - val_mae: 0.0928
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093 - mae: 0.0532 - val_loss: 0.0088 - val_mae: 0.0738
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0119 - mae: 0.0598 - val_loss: 0.0240 - val_mae: 0.1287
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138 - mae: 0.0664 - val_loss: 0.0201 - val_mae: 0.1186
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mae: 0.0570 - val_loss: 0.0203 - val_mae: 0.1169
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - mae: 0.0551 - val_loss: 0.0176 - val_mae: 0.1064
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124 - mae: 0.0510 - val_loss: 0.0165 - val_mae: 0.1005
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - mae: 0.0566 - val_loss: 0.0245 - val_mae: 0.1275
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106 - mae: 0.0564 - val_loss: 0.0190 - val_mae: 0.1077
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - mae: 0.0537 - val_loss: 0.0075 - val_mae: 0.0664
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - mae: 0.0498 - val_loss: 0.0110 - val_mae: 0.0799
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - mae: 0.0499 - val_loss: 0.0175 - val_mae: 0.1021
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - mae: 0.0525 - val_loss: 0.0115 - val_mae: 0.0822
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142 - mae: 0.0574 - val_loss: 0.0079 - val_mae: 0.0732
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - mae: 0.0743
# Test Loss: 0.0079, MAE: 0.0732
# MSE : 0.007912642233411501

# %%
# Similary as random forest combine tabular and embedding data and split
# use previous data of 7 dayas to capture historical data
# make a sequential lstm model having two hidden layers.
# dont use softmax as activation, use sigmoid or relu which will be the best according to my needs
# Evaluate the model performance and plot actual vs predictions
# add dates along x axis

# %% [markdown]
# ## **Tunned Lstm**

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Function to create the model with tunable hyperparameters
def build_model(hp):
    model = Sequential()
    # LSTM layer 1
    model.add(LSTM(
        units=hp.Int('units_lstm_1', min_value=32, max_value=256, step=32),
        return_sequences=True,
        input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    
    # LSTM layer 2
    model.add(LSTM(
        units=hp.Int('units_lstm_2', min_value=32, max_value=128, step=32)
    ))
    
    # Dense layers
    model.add(Dense(units=hp.Int('dense_units', 16, 64, step=16), activation='relu'))
    model.add(Dense(1))

    model.compile(
        optimizer=Adam(
            learning_rate=hp.Choice('learning_rate', values=[1e-2, 5e-4, 1e-4])
        ),loss='mean_squared_error', metrics=['mae'] )

    return model

tuner = kt.RandomSearch(
    build_model, objective='val_loss', max_trials=10, executions_per_trial=1
    # directory='lstm_tuner', project_name='bitcoin_price_prediction'
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

tuner.search(
    X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
    callbacks=[early_stop], verbose=1)

# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]


y_pred = best_model.predict(X_test)
loss, mae = best_model.evaluate(X_test, y_test)
print(f"Best Hyperparameters:\n{best_hps.values}")
print(f"Test Loss: {loss:.4f}, MAE: {mae:.4f}")
print('Test MSE:', mean_squared_error(y_test, y_pred))

plt.figure(figsize=(14, 6))
plt.plot(df['Date'].values[-len(y_test):], y_test, label='Actual Price')
plt.plot(df['Date'].values[-len(y_test):], y_pred.flatten(), label='Predicted Price')
plt.title('Optimized LSTM Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price (Standardized)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Trial 10 Complete [00h 00m 06s]
# val_loss: 0.025922885164618492
#
# Best val_loss So Far: 0.004829742480069399
# Total elapsed time: 00h 01m 13s
# Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0561
# Best Hyperparameters:
# {'units_lstm_1': 96, 'dropout_1': 0.2, 'units_lstm_2': 96, 'dense_units': 32, 'learning_rate': 0.01}
# Test Loss: 0.0048, MAE: 0.0547
# Test MSE: 0.004829742225517132

# %%
# tune the lstm model using grid search or keras tunner. which will be best
# use early stoping to decide the number of epoches dynamically
# print best hyperparameter values
# it is behaving same as lstm add multiple option in layers so that it can decide its
# neurons which give best results

# %% [markdown]
# ## **LSTM with Hybrid Fusion**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM, Concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

scaler = StandardScaler()
tabular = scaler.fit_transform(df[['Open', 'High', 'Low', 'Close', 'Volume']].values)
target_scaler = StandardScaler()
y = target_scaler.fit_transform(df[['Adj Close']]).flatten()

def create_sequences(data, y, window_size=7):
    X_seq, y_seq = [], []
    for i in range(window_size, len(data)):
        X_seq.append(data[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)
X_tabular_seq, y_seq = create_sequences(tabular, y)

reduced_embeddings_seq = reduced_embeddings[7:]  # past 7 daus embrddings

X_train_tab, X_test_tab, X_train_emb, X_test_emb, y_train, y_test = train_test_split(
    X_tabular_seq, reduced_embeddings_seq, y_seq, test_size=0.2, shuffle=False
)

# Tabular Branch (LSTM)
tab_input = Input(shape=(X_train_tab.shape[1], X_train_tab.shape[2]))
x1 = LSTM(64, return_sequences=False)(tab_input)
x1 = Dropout(0.3)(x1)
# Embedding Branch (Dense)
emb_input = Input(shape=(X_train_emb.shape[1],))
x2 = Dense(128, activation='relu')(emb_input)
x2 = Dropout(0.3)(x2)
x2 = Dense(64, activation='relu')(x2)

combined = Concatenate()([x1, x2]) # combining for fusion
z = Dense(64, activation='relu')(combined)
z = Dropout(0.2)(z)
output = Dense(1)(z)

model = Model(inputs=[tab_input, emb_input], outputs=output)
model.compile(optimizer=Adam(0.0005), loss='mse', metrics=['mae'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit([X_train_tab, X_train_emb], y_train,
    validation_data=([X_test_tab, X_test_emb], y_test), epochs=100, batch_size=32,
    callbacks=[early_stop], verbose=1)

y_pred = model.predict([X_test_tab, X_test_emb])
mse = np.mean((y_pred.flatten() - y_test) ** 2)
mae = np.mean(np.abs(y_pred.flatten() - y_test))
print(f"MSE: {mse:.4f}, MAE: {mae:.4f}")

test_size = len(y_test)
dates_test = df['Date'].values[-test_size:]
plt.figure(figsize=(14, 6))
plt.plot(dates_test, y_test, label='Actual Price', color='blue')
plt.plot(dates_test, y_pred.flatten(), label='Predicted Price', color='orange')
plt.title('Hybrid Fusion Model: Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Adj Close ')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.6972 - mae: 0.6310 - val_loss: 0.3034 - val_mae: 0.5109
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1144 - mae: 0.2302 - val_loss: 0.0315 - val_mae: 0.1487
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0846 - mae: 0.1859 - val_loss: 0.0131 - val_mae: 0.0843
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0700 - mae: 0.1810 - val_loss: 0.0239 - val_mae: 0.1203
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0667 - mae: 0.1723 - val_loss: 0.0135 - val_mae: 0.0873
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0665 - mae: 0.1606 - val_loss: 0.0135 - val_mae: 0.0876
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0541 - mae: 0.1586 - val_loss: 0.0149 - val_mae: 0.0961
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0495 - mae: 0.1490 - val_loss: 0.0143 - val_mae: 0.0966
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0481 - mae: 0.1449 - val_loss: 0.0139 - val_mae: 0.0899
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368 - mae: 0.1320 - val_loss: 0.0196 - val_mae: 0.1100
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0363 - mae: 0.1344 - val_loss: 0.0107 - val_mae: 0.0830
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0404 - mae: 0.1361 - val_loss: 0.0130 - val_mae: 0.0889
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0529 - mae: 0.1468 - val_loss: 0.0114 - val_mae: 0.0834
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0473 - mae: 0.1362 - val_loss: 0.0128 - val_mae: 0.0895
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0385 - mae: 0.1284 - val_loss: 0.0134 - val_mae: 0.0930
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0353 - mae: 0.1348 - val_loss: 0.0063 - val_mae: 0.0589
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0411 - mae: 0.1303 - val_loss: 0.0106 - val_mae: 0.0795
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0317 - mae: 0.1213 - val_loss: 0.0071 - val_mae: 0.0608
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0424 - mae: 0.1375 - val_loss: 0.0096 - val_mae: 0.0736
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0416 - mae: 0.1323 - val_loss: 0.0154 - val_mae: 0.0977
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0352 - mae: 0.1270 - val_loss: 0.0064 - val_mae: 0.0609
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0392 - mae: 0.1242 - val_loss: 0.0065 - val_mae: 0.0623
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0358 - mae: 0.1272 - val_loss: 0.0063 - val_mae: 0.0595
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0400 - mae: 0.1247 - val_loss: 0.0100 - val_mae: 0.0766
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0549 - mae: 0.1441 - val_loss: 0.0064 - val_mae: 0.0591
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0412 - mae: 0.1283 - val_loss: 0.0097 - val_mae: 0.0781
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0451 - mae: 0.1306 - val_loss: 0.0090 - val_mae: 0.0751
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0356 - mae: 0.1255 - val_loss: 0.0053 - val_mae: 0.0514
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mae: 0.1048 - val_loss: 0.0076 - val_mae: 0.0658
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0397 - mae: 0.1213 - val_loss: 0.0047 - val_mae: 0.0493
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0435 - mae: 0.1281 - val_loss: 0.0057 - val_mae: 0.0542
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0413 - mae: 0.1248 - val_loss: 0.0049 - val_mae: 0.0498
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0287 - mae: 0.1105 - val_loss: 0.0049 - val_mae: 0.0504
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0355 - mae: 0.1170 - val_loss: 0.0109 - val_mae: 0.0856
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0504 - mae: 0.1286 - val_loss: 0.0047 - val_mae: 0.0498
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0303 - mae: 0.1165 - val_loss: 0.0075 - val_mae: 0.0665
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255 - mae: 0.1079 - val_loss: 0.0066 - val_mae: 0.0598
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0493 - mae: 0.1295 - val_loss: 0.0066 - val_mae: 0.0595
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0254 - mae: 0.1067 - val_loss: 0.0056 - val_mae: 0.0526
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0447 - mae: 0.1304 - val_loss: 0.0056 - val_mae: 0.0583
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# MSE: 0.0047, MAE: 0.0493

# %%
# can we apply fustion technique with lstm if yes then how
# which will be the best for my case
# so use hybrid fusion 
# I think we should set lstm model on the tabular data first and then combined it with the
# embeddings for final output. because i think we should capture the tabular context first
# and then combine with embeddings to capture tweet context
# add early stoping in it and also use validation technique as we done previously
# plot a graph of actual and pred againt date
# add evaluation matrices

# %% [markdown]
# # **XG Boost**

# %%
import xgboost as xgb

scaler = StandardScaler()
tabular_data = df[['Open', 'High', 'Low', 'Close',  'Volume']].values
tabular_data_scaled = scaler.fit_transform(tabular_data)
X_combined = np.concatenate([tabular_data_scaled, reduced_embeddings], axis=1)
target_scaler = StandardScaler()
y = target_scaler.fit_transform(df[['Adj Close']]).flatten()

def create_sequences(data, targets, window_size=7):
    X, y_seq = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y_seq.append(targets[i])
    return np.array(X), np.array(y_seq)
X_sequences, y_sequences = create_sequences(X_combined, y)

X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_sequences, test_size=0.2, shuffle=False)
X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
X_test_reshaped = X_test.reshape(X_test.shape[0], -1)

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, 
                             learning_rate=0.01, max_depth=6, colsample_bytree=0.8, 
                             subsample=0.8)

xgb_model.fit(X_train_reshaped, y_train, eval_metric="rmse", 
              early_stopping_rounds=10, eval_set=[(X_test_reshaped, y_test)], verbose=True)
y_pred = xgb_model.predict(X_test_reshaped)
print('MSE:', mean_squared_error(y_test, y_pred))

test_size = len(y_test)
dates_test = df['Date'].values[-test_size:]
plt.figure(figsize=(14, 6))
plt.plot(dates_test, y_test, label='Actual Price')
plt.plot(dates_test, y_pred, label='Predicted Price')
plt.title('XGBoost Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#
# [91]	validation_0-rmse:0.28577
# [92]	validation_0-rmse:0.28294
# [93]	validation_0-rmse:0.28010
# [94]	validation_0-rmse:0.27703
# [95]	validation_0-rmse:0.27439
# [96]	validation_0-rmse:0.27155
# [97]	validation_0-rmse:0.26884
# [98]	validation_0-rmse:0.26575
# [99]	validation_0-rmse:0.26283
# [100]	validation_0-rmse:0.26020
# [101]	validation_0-rmse:0.25739
# [102]	validation_0-rmse:0.25468
# [103]	validation_0-rmse:0.25231
# [104]	validation_0-rmse:0.24992
# [105]	validation_0-rmse:0.24732
# [106]	validation_0-rmse:0.24466
# [107]	validation_0-rmse:0.24231
# [108]	validation_0-rmse:0.24004
# [109]	validation_0-rmse:0.23759
# [110]	validation_0-rmse:0.23508
# [111]	validation_0-rmse:0.23262
# [112]	validation_0-rmse:0.23021
# [113]	validation_0-rmse:0.22811
# [114]	validation_0-rmse:0.22579
# [115]	validation_0-rmse:0.22341
# [116]	validation_0-rmse:0.22107
# [117]	validation_0-rmse:0.21879
# [118]	validation_0-rmse:0.21674
# [119]	validation_0-rmse:0.21451
# [120]	validation_0-rmse:0.21247
# [121]	validation_0-rmse:0.21050
# [122]	validation_0-rmse:0.20841
# [123]	validation_0-rmse:0.20625
# [124]	validation_0-rmse:0.20410
# [125]	validation_0-rmse:0.20193
# [126]	validation_0-rmse:0.20021
# [127]	validation_0-rmse:0.19819
# [128]	validation_0-rmse:0.19620
# [129]	validation_0-rmse:0.19445
# [130]	validation_0-rmse:0.19235
# [131]	validation_0-rmse:0.19051
# [132]	validation_0-rmse:0.18880
# [133]	validation_0-rmse:0.18718
# [134]	validation_0-rmse:0.18524
# [135]	validation_0-rmse:0.18371
# [136]	validation_0-rmse:0.18138
# [137]	validation_0-rmse:0.17945
# [138]	validation_0-rmse:0.17789
# [139]	validation_0-rmse:0.17645
# [140]	validation_0-rmse:0.17487
# [141]	validation_0-rmse:0.17316
# [142]	validation_0-rmse:0.17142
# [143]	validation_0-rmse:0.16955
# [144]	validation_0-rmse:0.16815
# [145]	validation_0-rmse:0.16668
# [146]	validation_0-rmse:0.16479
# [147]	validation_0-rmse:0.16332
# [148]	validation_0-rmse:0.16168
# [149]	validation_0-rmse:0.16001
# [150]	validation_0-rmse:0.15837
# [151]	validation_0-rmse:0.15690
# [152]	validation_0-rmse:0.15558
# [153]	validation_0-rmse:0.15372
# [154]	validation_0-rmse:0.15217
# [155]	validation_0-rmse:0.15084
# [156]	validation_0-rmse:0.14950
# [157]	validation_0-rmse:0.14812
# [158]	validation_0-rmse:0.14707
# [159]	validation_0-rmse:0.14571
# [160]	validation_0-rmse:0.14440
# [161]	validation_0-rmse:0.14281
# [162]	validation_0-rmse:0.14142
# [163]	validation_0-rmse:0.14010
# [164]	validation_0-rmse:0.13871
# [165]	validation_0-rmse:0.13749
# [166]	validation_0-rmse:0.13605
# [167]	validation_0-rmse:0.13479
# [168]	validation_0-rmse:0.13347
# [169]	validation_0-rmse:0.13220
# [170]	validation_0-rmse:0.13091
# [171]	validation_0-rmse:0.12941
# [172]	validation_0-rmse:0.12823
# [173]	validation_0-rmse:0.12708
# [174]	validation_0-rmse:0.12629
# [175]	validation_0-rmse:0.12505
# [176]	validation_0-rmse:0.12372
# [177]	validation_0-rmse:0.12295
# [178]	validation_0-rmse:0.12179
# [179]	validation_0-rmse:0.12058
# [180]	validation_0-rmse:0.11955
# [181]	validation_0-rmse:0.11861
# [182]	validation_0-rmse:0.11772
# [183]	validation_0-rmse:0.11667
# [184]	validation_0-rmse:0.11576
# [185]	validation_0-rmse:0.11470
# [186]	validation_0-rmse:0.11361
# [187]	validation_0-rmse:0.11233
# [188]	validation_0-rmse:0.11144
# [189]	validation_0-rmse:0.11016
# [190]	validation_0-rmse:0.10924
# [191]	validation_0-rmse:0.10835
# [192]	validation_0-rmse:0.10759
# [193]	validation_0-rmse:0.10669
# [194]	validation_0-rmse:0.10573
# [195]	validation_0-rmse:0.10489
# [196]	validation_0-rmse:0.10419
# [197]	validation_0-rmse:0.10339
# [198]	validation_0-rmse:0.10249
# [199]	validation_0-rmse:0.10179
# [200]	validation_0-rmse:0.10094
# [201]	validation_0-rmse:0.10028
# [202]	validation_0-rmse:0.09941
# [203]	validation_0-rmse:0.09837
# [204]	validation_0-rmse:0.09780
# [205]	validation_0-rmse:0.09707
# [206]	validation_0-rmse:0.09627
# [207]	validation_0-rmse:0.09553
# [208]	validation_0-rmse:0.09483
# [209]	validation_0-rmse:0.09432
# [210]	validation_0-rmse:0.09353
# [211]	validation_0-rmse:0.09300
# [212]	validation_0-rmse:0.09236
# [213]	validation_0-rmse:0.09175
# [214]	validation_0-rmse:0.09109
# [215]	validation_0-rmse:0.09056
# [216]	validation_0-rmse:0.08997
# [217]	validation_0-rmse:0.08920
# [218]	validation_0-rmse:0.08863
# [219]	validation_0-rmse:0.08794
# [220]	validation_0-rmse:0.08717
# [221]	validation_0-rmse:0.08664
# [222]	validation_0-rmse:0.08607
# [223]	validation_0-rmse:0.08558
# [224]	validation_0-rmse:0.08501
# [225]	validation_0-rmse:0.08468
# [226]	validation_0-rmse:0.08442
# [227]	validation_0-rmse:0.08395
# [228]	validation_0-rmse:0.08337
# [229]	validation_0-rmse:0.08298
# [230]	validation_0-rmse:0.08235
# [231]	validation_0-rmse:0.08196
# [232]	validation_0-rmse:0.08156
# [233]	validation_0-rmse:0.08128
# [234]	validation_0-rmse:0.08089
# [235]	validation_0-rmse:0.08042
# [236]	validation_0-rmse:0.08016
# [237]	validation_0-rmse:0.07976
# [238]	validation_0-rmse:0.07946
# [239]	validation_0-rmse:0.07912
# [240]	validation_0-rmse:0.07876
# [241]	validation_0-rmse:0.07838
# [242]	validation_0-rmse:0.07800
# [243]	validation_0-rmse:0.07772
# [244]	validation_0-rmse:0.07743
# [245]	validation_0-rmse:0.07698
# [246]	validation_0-rmse:0.07673
# [247]	validation_0-rmse:0.07633
# [248]	validation_0-rmse:0.07605
# [249]	validation_0-rmse:0.07570
# [250]	validation_0-rmse:0.07543
# [251]	validation_0-rmse:0.07518
# [252]	validation_0-rmse:0.07495
# [253]	validation_0-rmse:0.07476
# [254]	validation_0-rmse:0.07450
# [255]	validation_0-rmse:0.07423
# [256]	validation_0-rmse:0.07405
# [257]	validation_0-rmse:0.07370
# [258]	validation_0-rmse:0.07342
# [259]	validation_0-rmse:0.07324
# [260]	validation_0-rmse:0.07298
# [261]	validation_0-rmse:0.07274
# [262]	validation_0-rmse:0.07253
# [263]	validation_0-rmse:0.07242
# [264]	validation_0-rmse:0.07221
# [265]	validation_0-rmse:0.07201
# [266]	validation_0-rmse:0.07187
# [267]	validation_0-rmse:0.07171
# [268]	validation_0-rmse:0.07153
# [269]	validation_0-rmse:0.07137
# [270]	validation_0-rmse:0.07122
# [271]	validation_0-rmse:0.07106
# [272]	validation_0-rmse:0.07096
# [273]	validation_0-rmse:0.07080
# [274]	validation_0-rmse:0.07077
# [275]	validation_0-rmse:0.07064
# [276]	validation_0-rmse:0.07052
# [277]	validation_0-rmse:0.07038
# [278]	validation_0-rmse:0.07029
# [279]	validation_0-rmse:0.07014
# [280]	validation_0-rmse:0.07002
# [281]	validation_0-rmse:0.06987
# [282]	validation_0-rmse:0.06978
# [283]	validation_0-rmse:0.06971
# [284]	validation_0-rmse:0.06964
# [285]	validation_0-rmse:0.06952
# [286]	validation_0-rmse:0.06941
# [287]	validation_0-rmse:0.06928
# [288]	validation_0-rmse:0.06922
# [289]	validation_0-rmse:0.06919
# [290]	validation_0-rmse:0.06910
# [291]	validation_0-rmse:0.06908
# [292]	validation_0-rmse:0.06903
# [293]	validation_0-rmse:0.06896
# [294]	validation_0-rmse:0.06895
# [295]	validation_0-rmse:0.06887
# [296]	validation_0-rmse:0.06890
# [297]	validation_0-rmse:0.06885
# [298]	validation_0-rmse:0.06883
# [299]	validation_0-rmse:0.06877
# [300]	validation_0-rmse:0.06875
# [301]	validation_0-rmse:0.06871
# [302]	validation_0-rmse:0.06866
# [303]	validation_0-rmse:0.06863
# [304]	validation_0-rmse:0.06858
# [305]	validation_0-rmse:0.06856
# [306]	validation_0-rmse:0.06852
# [307]	validation_0-rmse:0.06847
# [308]	validation_0-rmse:0.06842
# [309]	validation_0-rmse:0.06843
# [310]	validation_0-rmse:0.06841
# [311]	validation_0-rmse:0.06840
# [312]	validation_0-rmse:0.06841
# [313]	validation_0-rmse:0.06850
# [314]	validation_0-rmse:0.06851
# [315]	validation_0-rmse:0.06851
# [316]	validation_0-rmse:0.06851
# [317]	validation_0-rmse:0.06853
# [318]	validation_0-rmse:0.06856
# [319]	validation_0-rmse:0.06860
# [320]	validation_0-rmse:0.06858
# MSE: 0.004678163155895941

# %%
# will xg boost will be best for my bitcoin analysis
# built xg boost model on my dataset
# can we give it a sequence as we gave to lstm because as xg boost learn from sequential error
# and correct them 
# I think we need to reshape the features befor feeding into the model 
# Evaluate model performance and plot the graph

# %% [markdown]
# ## **XAI on XG Boost**

# %%
explainer = shap.Explainer(xgb_model)
shap_values = explainer(X_test_reshaped)
shap.summary_plot(shap_values, X_test_reshaped)

# %%
# apply shap on xg boost
# give a summary plot
